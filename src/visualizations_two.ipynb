# %%
import pandas as pd
import scipy.stats as stats
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from initial_clean import *
from filtering_fuctions import *

# %%
high_perf_schools = DataFilter(df)

# %%
filter_high_perf_schools(high_perf_schools)

# %%
high_perf_schools.df['grade'].unique()
# Out:
# array(['08', '05', 'HS'], dtype=object)

# %%
# school_name = list(high_perf_schools.df['school_name'])
# participation_rate = list(high_perf_schools.df['participation_rate'])

# fig, axs = plt.subplots(2, 1, figsize=(9,9))
# axs[0].bar(school_name, participation_rate)
# axs[1].scatter(school_name, participation_rate)
# fig.suptitle("High Performing Schools' Participation Rate")
# plt.show()

# %%
high_perf_schools.df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 501 entries, 795 to 4630
# Data columns (total 26 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   level                501 non-null    object
#  1   district_code        501 non-null    object
#  2   district_name        501 non-null    object
#  3   school_code          501 non-null    object
#  4   school_name          501 non-null    object
#  5   grade                501 non-null    object
#  6   num_total_rec        501 non-null    object
#  7   num_valid_scores     501 non-null    object
#  8   num_no_scores        501 non-null    object
#  9   participation_rate   501 non-null    object
#  10  mean_scale_score_19  501 non-null    object
#  11  std_scale_score_19   501 non-null    object
#  12  mean_scale_score_18  494 non-null    object
#  13  num_pme_19           501 non-null    object
#  14  percent_pme_19       501 non-null    object
# ...

# %%
participation_rate(high_perf_schools)
high_perf_schools.df.hist(column='participation_rate', bins = 40)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fbda0d80550>]],
#       dtype=object)

# %%
passing_schools = DataFilter(df)
filter_met_or_exceed_expectations_schools(passing_schools)
participation_rate(passing_schools)

# %%
passing_schools.df.hist(column='participation_rate', bins = 50)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fbda0e7f710>]],
#       dtype=object)

# %%
high_perf_schools.df.groupby('district_name').hist(column='participation_rate', bins = 40)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/pandas/plotting/_matplotlib/tools.py:182: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure(**fig_kw)
# district_name
# ACADEMY 20                    [[AxesSubplot(0.125,0.125;0.775x0.755)]]
# ADAMS 12 FIVE STAR SCHOOLS    [[AxesSubplot(0.125,0.125;0.775x0.755)]]
# ADAMS-ARAPAHOE 28J            [[AxesSubplot(0.125,0.125;0.775x0.755)]]
# BOULDER VALLEY RE 2           [[AxesSubplot(0.125,0.125;0.775x0.755)]]
# CANON CITY RE-1               [[AxesSubplot(0.125,0.125;0.775x0.755)]]
# CHARTER SCHOOL INSTITUTE      [[AxesSubplot(0.125,0.125;0.775x0.755)]]
# CHERRY CREEK 5                [[AxesSubplot(0.125,0.125;0.775x0.755)]]
# CHEYENNE MOUNTAIN 12          [[AxesSubplot(0.125,0.125;0.775x0.755)]]
# ...

# %%
districts_with_ten_or_more_results(high_perf_schools)
high_perf_schools.df.groupby('district_name').hist(column='participation_rate', bins = 40)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-a86e85382f9d> in <module>
#       1 #districts_with_ten_or_more_results(high_perf_schools)
# ----> 2 districts_with_ten_or_more_results(high_perf_schools).df.groupby('district_name').hist(column='participation_rate', bins = 40)
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'df'
