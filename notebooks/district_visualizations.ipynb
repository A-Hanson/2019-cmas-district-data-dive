# %%
import pandas as pd
import scipy.stats as stats
import matplotlib.pyplot as plt
import seaborn as sns

from src.initial_clean import *
from src.filtering_fuctions import *

# %%
district = DataFilter(df)
district.filter_for_district()
district.df.describe()
# Out:
#        participation_rate  mean_scale_score_19  std_scale_score_19  \
# count          550.000000           550.000000          550.000000
# mean            88.903818           587.530909           99.560000
# std             16.118387            40.440583           15.619189
# min             20.600000           431.000000           46.000000
# 25%             87.400000           562.000000           90.000000
# 50%             94.900000           588.000000          101.000000
# 75%             98.300000           614.000000          110.000000
# max            100.000000           744.000000          137.000000
#
#        mean_scale_score_18  percent_pme_19  percent_ae_19  percent_me_19  \
# count           550.000000      550.000000     550.000000     550.000000
# mean            569.445455       31.104182      34.709455      10.312545
# std             111.394259       15.897985      15.968865      15.396557
# min               0.000000        0.000000       0.000000       0.000000
# 25%             560.000000       20.700000      30.425000       0.000000
# 50%             591.000000       30.800000      37.200000       0.000000
# 75%             614.000000       40.850000      44.300000      22.850000
# max             700.000000       84.800000      73.900000      55.000000
#
#        percent_ee_19  percent_me_or_ee_19  percent_me_or_ee_18  \
# count     550.000000           550.000000           550.000000
# mean        1.360000            25.993273            25.528545
# std         2.619411            15.429139            15.216749
# min         0.000000             0.000000             0.000000
# 25%         0.000000            15.000000            14.550000
# 50%         0.000000            24.500000            25.900000
# 75%         1.900000            36.200000            35.550000
# max        22.200000            94.100000            72.000000
#
#        change_in_me_or_ee
# count          550.000000
# mean            -0.353636
# std              7.812081
# min            -29.400000
# 25%             -4.075000
# 50%              0.000000
# 75%              2.575000
# max             38.200000

# %%
district.met_or_exceeded_expectations()
# Out:
#         level district_code                 district_name school_code  \
# 15   DISTRICT          0010                    MAPLETON 1        0000
# 16   DISTRICT          0010                    MAPLETON 1        0000
# 17   DISTRICT          0010                    MAPLETON 1        0000
# 18   DISTRICT          0010                    MAPLETON 1        0000
# 19   DISTRICT          0020    ADAMS 12 FIVE STAR SCHOOLS        0000
# ..        ...           ...                           ...         ...
# 742  DISTRICT          9130           EXPEDITIONARY BOCES        0000
# 743  DISTRICT          9170  EDUCATION REENVISIONED BOCES        0000
# 744  DISTRICT          9170  EDUCATION REENVISIONED BOCES        0000
# 745  DISTRICT          9170  EDUCATION REENVISIONED BOCES        0000
# 746  DISTRICT          9170  EDUCATION REENVISIONED BOCES        0000
#
#      school_name       grade num_total_rec num_valid_scores num_no_scores  \
# 15   All Schools  All Grades         2,024            1,666           358
# 16   All Schools          05           626              571            55
# 17   All Schools          08           703              591           112
# 18   All Schools          HS           695              504           191
# 19   All Schools  All Grades         8,842            7,793         1,049
# ..           ...         ...           ...              ...           ...
# 742  All Schools          HS            20               18             2
# 743  All Schools  All Grades           674              236           438
# 744  All Schools          05           101               44            57
# 745  All Schools          08           273              107           166
# 746  All Schools          HS           300               85           215
#
#      participation_rate  ...  percent_ae_19  num_me_19  percent_me_19  \
# 15                 82.3  ...           37.6        219           13.1
# 16                 91.2  ...           35.0          0            0.0
# 17                 84.1  ...           30.6         67           11.3
# 18                 72.5  ...           48.8          0            0.0
# 19                 88.1  ...           34.3      2,217           28.4
# ..                  ...  ...            ...        ...            ...
# 742                90.0  ...            0.0          0            0.0
# 743                35.0  ...           36.4          0            0.0
# 744                43.6  ...           31.8          0            0.0
# 745                39.2  ...           26.2          0            0.0
# 746                28.3  ...           51.8          0            0.0
#
#     num_ee_19  percent_ee_19 num_me_or_ee_19  percent_me_or_ee_19  \
# 15          6            0.4             225                 13.5
# 16          0            0.0              90                 15.8
# 17          3            0.5              70                 11.8
# 18          0            0.0              65                 12.9
# 19        299            3.8           2,516                 32.3
# ..        ...            ...             ...                  ...
# 742         0            0.0               6                 33.3
# 743         0            0.0              41                 17.4
# 744         0            0.0               5                 11.4
# 745         0            0.0              20                 18.7
# 746         0            0.0              16                 18.8
#
#     num_me_or_ee_18  percent_me_or_ee_18 change_in_me_or_ee
# 15              197                 12.0                1.5
# 16               68                 13.2                2.6
# 17               69                 10.7                1.1
# 18               60                 12.4                0.5
# 19            2,548                 32.0                0.3
# ..              ...                  ...                ...
# 742              10                 50.0              -16.7
# 743              59                 19.5               -2.1
# 744               9                 15.3               -3.9
# 745              21                 17.5                1.2
# 746              29                 23.6               -4.8
#
# [504 rows x 26 columns]

# %%
district.filter_for_all_grades()
district.df.describe()
# Out:
#        participation_rate  mean_scale_score_19  std_scale_score_19  \
# count          157.000000            157.00000          157.000000
# mean            88.538217            588.33121           99.675159
# std             14.399655             34.90103           13.169125
# min             23.000000            491.00000           54.000000
# 25%             85.100000            565.00000           93.000000
# 50%             93.200000            588.00000          101.000000
# 75%             97.400000            612.00000          109.000000
# max            100.000000            679.00000          126.000000
#
#        mean_scale_score_18  percent_pme_19  percent_ae_19  percent_me_19  \
# count           157.000000      157.000000     157.000000     157.000000
# mean            586.808917       31.894268      40.477070      14.568790
# std              57.635919       12.870530       8.046825      15.887178
# min               0.000000        0.000000       0.000000       0.000000
# 25%             567.000000       21.700000      35.700000       0.000000
# 50%             592.000000       31.100000      39.800000      10.400000
# 75%             614.000000       40.000000      45.300000      28.100000
# max             668.000000       69.700000      66.700000      49.700000
#
#        percent_ee_19  percent_me_or_ee_19  percent_me_or_ee_18  \
# count     157.000000           157.000000           157.000000
# mean        1.794904            27.117834            27.073248
# std         2.658822            12.099579            12.620046
# min         0.000000             4.900000             0.000000
# 25%         0.000000            18.700000            17.700000
# 50%         0.300000            25.100000            26.200000
# 75%         2.800000            36.100000            35.300000
# max        16.600000            62.300000            59.200000
#
#        change_in_me_or_ee
# count          157.000000
# mean            -0.488535
# std              6.695971
# min            -29.000000
# 25%             -3.900000
# 50%             -0.200000
# 75%              2.700000
# max             20.500000

# %%
sns.set(font_scale=1.5, style= "whitegrid")
#sns.set_style("whitegrid")
g = sns.pairplot(district.df, palette= "muted", 
                    x_vars=['participation_rate', 'mean_scale_score_19'],
                    y_vars=['percent_me_or_ee_19', 'change_in_me_or_ee'],
                    height=4)
plt.tight_layout()
plt.savefig("district_pair_plot_initial.png",
           transparent=True)

# %%
h = sns.pairplot(district.df, palette= "muted",
                 vars = ['participation_rate',
                 'percent_pme_19',
                 'percent_ae_19',
                 'percent_me_19',
                'percent_ee_19'],
                height=3)
h = h.map(plt.scatter)
plt.tight_layout()
plt.savefig("district_pair_plot_participation_and_scores.png",
           transparent=True)

# %%
plt.style.use('seaborn-muted')

fig, ax = plt.subplots(1, 1, figsize= (10,10))
ax.scatter(district.df['participation_rate'], 
           district.df['mean_scale_score_19'])
ax.axhline(650, linewidth=3, color="green", linestyle="solid", label="Met Expectations")
ax.set_xlim(20, 105)
ax.set_xlabel('Participation Rate', fontsize=20)
ax.set_ylabel('Mean Score', fontsize=20)
ax.set_title('District Level Participation Rate and Mean Scores 2019', fontsize=20)
ax.legend()
plt.tight_layout()
plt.savefig("district_participation_mean_scores.png")

# %%
test = DataFilter(df)
n = find_num_trials_district(test)
k = find_num_met_or_exceeds_district(test)
p = 0.5

binomial = stats.binom(n, p)

fig, ax = plt.subplots(1, figsize=(16, 8))
bars = ax.bar(range(n+1), [binomial.pmf(i) for i in range(n+1)],
             align="center")
ax.set_xlim(0, 110)

ax.axvline(k, linewidth=3, color='green', linestyle= "--", label='Actual Number of Districts that Met or Exceeded Expectations')

ax.set_xlabel('Number of Districts', fontsize=20)
ax.set_ylabel('Probability', fontsize=20)
ax.set_title("Districts that Met or Exceeded Expectations Under the Null Hypothesis", fontsize = 25)
ax.legend()
plt.tight_layout()
